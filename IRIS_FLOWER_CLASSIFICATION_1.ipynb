# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwaj15/IRIS-FLOWER-CLASSIFICATION/blob/main/IRIS_FLOWER_CLASSIFICATION_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IRIS FLOWER CLASSIFICATION**

# %% [markdown]
# ### **AIM**: Classifing iris flowers amoung three species they are:
#
#
# ---
#
#
# * Iris Setosa
# * Iris Versicolour
# * Iris Virginica
#
# The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.

# %% [markdown]
# ***IMPORTING LIBRARIES***
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
#
#
#
# # 1.   **Importing dataset**
#
#
#
#
# ---

# %%
columns = ['Sepal length(cm)', 'Sepal width(cm)', 'Petal length(cm)', 'Petal width(cm)', 'Species'] 
# Import iris dataset
df = pd.read_csv('/content/archive (1).zip', names=columns)
df
# Out:
#      Sepal length(cm)  Sepal width(cm)  Petal length(cm)  Petal width(cm)  \
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %% [markdown]
# ---
#
#
#
# * To View the information of the data frame that contains details.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sepal length(cm)  150 non-null    float64
#  1   Sepal width(cm)   150 non-null    float64
#  2   Petal length(cm)  150 non-null    float64
#  3   Petal width(cm)   150 non-null    float64
#  4   Species           150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ---
#
#
# * To check whether there are any missing values, then modify them
# before using the dataset. For modifying you can use the fillna() method. It will fill null values.
#
# ---

# %%
#checking for null values
df.isnull().sum()
# Out:
# Sepal length(cm)    0
# Sepal width(cm)     0
# Petal length(cm)    0
# Petal width(cm)     0
# Species             0
# dtype: int64

# %% [markdown]
# > We can see that all values are 0. It means that there are no null values over the entire data frame.

# %% [markdown]
# ---
#
#
# * To View the column names in the data frame, use columns
#
# ---

# %%
df.columns
# Out:
# Index(['Sepal length(cm)', 'Sepal width(cm)', 'Petal length(cm)',
#        'Petal width(cm)', 'Species'],
#       dtype='object')

# %% [markdown]
# ---
#
#
# * To View the statistical description of the dataset.
#
# ---
#
#
#
#
#
#
#
#
# >

# %%
df.describe()
# Out:
#        Sepal length(cm)  Sepal width(cm)  Petal length(cm)  Petal width(cm)
# count        150.000000       150.000000        150.000000       150.000000
# mean           5.843333         3.054000          3.758667         1.198667
# std            0.828066         0.433594          1.764420         0.763161
# min            4.300000         2.000000          1.000000         0.100000
# 25%            5.100000         2.800000          1.600000         0.300000
# 50%            5.800000         3.000000          4.350000         1.300000
# 75%            6.400000         3.300000          5.100000         1.800000
# max            7.900000         4.400000          6.900000         2.500000

# %% [markdown]
# ---
#
#
#
#
#
# # 2. **Visualizations**
#
#
#
#
# ---

# %% [markdown]
# *   To View the count plot of species feature using seaborn.

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# Visualize the whole dataset
sns.pairplot(df, hue='Species')

# %% [markdown]
# ---
#
# # 3. **Data preparation**
#
#
# ---
# *  To Define 'x' and 'y'.
#
#
# > 'x' contains all the input variables such as independent features, and 'y' should contain the dependent variable which is dependent on independent variables, the output.

# %%
x=df.iloc[:,:4]
y=df.iloc[:,4]

# %% [markdown]
# To View 'x'

# %%
x
# Out:
#      Sepal length(cm)  Sepal width(cm)  Petal length(cm)  Petal width(cm)
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# To View 'y'

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# ---
#
#
#
# # 4. **Training the algorithm**
#
#
#
#
#
#
# ---
#
#
#
#
# > Import train_test_split to split the data into train and test datasets.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %% [markdown]
# * To View their shapes. Use the shape method to view.

# %%
x_train.shape
# Out:
# (112, 4)

# %%
x_test.shape
# Out:
# (38, 4)

# %%
y_train.shape
# Out:
# (112,)

# %%
y_test.shape
# Out:
# (38,)

# %% [markdown]
# ---
#
#
#
# #5. **Creating the Model (Classification)**
#
#
#
# ---

# %% [markdown]
# *  So here we are going to classify the Iris flowers dataset using
# logistic regression. For creating the model, import LogisticRegression from the sci-kit learn library.

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %% [markdown]
# *   Now train the model using the fit method. In the fit method, pass training datasets in it. x_train and y_train are the training datasets.

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ---
#
#
#
# #6.  **Making Predictions**
#
#
# ---

# %% [markdown]
# > Now we predict the results using predict method.

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %% [markdown]
# ---
#
#
#
# *  To Find the accuracy of the model and view the confusion matrix.
#
#
# ---

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]])

# %%
accuracy=accuracy_score(y_test,y_pred)*100
print("Accuracy of the model is {:.2f}".format(accuracy))
# Out:
# Accuracy of the model is 97.37

# %% [markdown]
# ---
#
# #7. **Conclusion on Classification**
#
# ---

# %% [markdown]
# >  Flower classification is a very important, simple, and basic project for any machine learning student. Every machine learning student should be thorough with the iris flowers dataset. This classification can be done by many classification algorithms in machine learning but in our article, we used logistic regression. Overall in this article, we have seen
#
#
#
#
#
# *   Mainly we focused on Logistic Regression.
# *  We took Iris Flowers dataset and performed a logistic regression algorithm.
# *   Finally, it classified flowers into their species.
# *   And we got an accuracy of 97.37%, which shows that the model we built is very accurate.

# %% [markdown]
# # ***THANK YOU...***
